# %% [markdown]
# A neural network is a computer system that has been modeled based on a biological neural network comprising neurons connected with each other. It can be built to solve machine learning tasks, like classification and regression problems.

# %% [markdown]
# The perceptron algorithm is a representation of how neural networks work.
# A perceptron is the most fundamental unit which is used to build a neural network. A perceptron resembles a neuron in the human brain.

# %% [markdown]
# ![Biological-neuron.png](attachment:Biological-neuron.png)

# %% [markdown]
# ![perceptron-single-layer-neural-network-comprising-of-single-neuron-768x332.png](attachment:perceptron-single-layer-neural-network-comprising-of-single-neuron-768x332.png)

# %% [markdown]
# Key concepts:
# - activation function (linear, sigmoid, relu, tahn, softmax)
# - feed-forward
# - backpropagation

# %%
from sklearn.datasets import make_moons, make_blobs
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Generate dataset
X, Y = make_blobs(n_samples=150,n_features=2,
                           centers=2,cluster_std=1.05,
                           random_state=2)

# %%
# Visualize dataset
plt.figure(figsize = (6, 6))
plt.scatter(X[:, 0], X[:, 1], c = Y)
plt.title('Ground truth', fontsize = 18)
plt.show()

# %%
print(Y)

# %%
class Perceptron:
    def __init__(self, features_len):
        # Init weights and bias
        pass
        
    def sigmoid(self, z):
        # Sigmoid formula
        pass
        
    def predict(self, X):
        # compoute Y_hat for a vector of values
        pass
    
    def cost_function(self, Y, Y_hat):
        # determine the total error
        pass
    
    def fit(self, X, Y, epochs=10, lr=0.01):
        # The train function, should have an iteration over all epochs and apply the gradient descent
        pass
    
    def gradient_descent_step(self, X, Y, Y_hat, alpha):
        # Take a step in the steepest direction 
        # Compute the new values for W and b
        pass

# %%
nn = Perceptron(len(X[0]))
print(X[0])
nn.fit(X, Y, epochs=1000)
